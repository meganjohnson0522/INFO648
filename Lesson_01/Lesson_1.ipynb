# %% [markdown]
# <a href="https://colab.research.google.com/github/meganjohnson0522/INFO648/blob/main/Lesson_01/Lesson_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# This is my first notebook.
# #This is bigger
# ##This is a little bigger
# $$\int5xdx$$

# %%
#this is my first code

print("Hello World!!!")
# Out:
# Hello World!!!

# %%
#import libraries

import pandas as pd

# %%
url = "https://raw.githubusercontent.com/JWarmenhoven/ISLR-python/master/Notebooks/Data/Wage.csv"

# %%
wage_df=pd.read_csv(url)

# %%
wage_df
# Out:
#       Unnamed: 0  year  age      sex            maritl      race  \
# 0         231655  2006   18  1. Male  1. Never Married  1. White
# 1          86582  2004   24  1. Male  1. Never Married  1. White
# 2         161300  2003   45  1. Male        2. Married  1. White
# 3         155159  2003   43  1. Male        2. Married  3. Asian
# 4          11443  2005   50  1. Male       4. Divorced  1. White
# ...          ...   ...  ...      ...               ...       ...
# 2995      376816  2008   44  1. Male        2. Married  1. White
# 2996      302281  2007   30  1. Male        2. Married  1. White
# 2997       10033  2005   27  1. Male        2. Married  2. Black
# 2998       14375  2005   27  1. Male  1. Never Married  1. White
# 2999      453557  2009   55  1. Male      5. Separated  1. White
#
#             education              region        jobclass          health  \
# 0        1. < HS Grad  2. Middle Atlantic   1. Industrial       1. <=Good
# ...

# %%
pd.crosstab(wage_df['region'],wage_df['education'])
pd.crosstab(wage_df['race'],wage_df['sex'])
# Out:
# sex       1. Male
# race
# 1. White     2480
# 2. Black      293
# 3. Asian      190
# 4. Other       37

# %%
pd.crosstab(wage_df['region'],wage_df['education'])
pd.crosstab(wage_df['race'],wage_df['education'])
# Out:
# education  1. < HS Grad  2. HS Grad  3. Some College  4. College Grad  \
# race
# 1. White            211         822              532              576
# 2. Black             31         105               92               40
# 3. Asian             15          31               18               66
# 4. Other             11          13                8                3
#
# education  5. Advanced Degree
# race
# 1. White                  339
# 2. Black                   25
# 3. Asian                   60
# 4. Other                    2

# %%
pd.crosstab(wage_df['region'],wage_df['education'])
pd.crosstab(wage_df['race'],wage_df['education'])
wage_df['education'].value_counts()
# Out:
# education
# 2. HS Grad            971
# 4. College Grad       685
# 3. Some College       650
# 5. Advanced Degree    426
# 1. < HS Grad          268
# Name: count, dtype: int64

# %%
wage_df.plot(x='age', y='wage', kind='scatter',alpha=.5)
# Out:
# <Axes: xlabel='age', ylabel='wage'>

# %%
wage_df.plot(x='year', y='wage', kind='scatter',title="my Scatter")
# Out:
# <Axes: title={'center': 'my Scatter'}, xlabel='year', ylabel='wage'>

# %%
import seaborn as sns

# %%
sns.stripplot(x='year', y='wage', data=wage_df, alpha=.5)
# Out:
# <Axes: xlabel='year', ylabel='wage'>

# %%
wage_df.boxplot(column='wage', by='education')
# Out:
# <Axes: title={'center': 'wage'}, xlabel='education'>

# %% [markdown]
# ADD NOTES
#
# From this data I learned that men with masters degrees tend to make more money see boxplot....
